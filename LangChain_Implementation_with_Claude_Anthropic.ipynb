# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehfuz-alam/LangChain-Implementation-with-Claude-Anthropic/blob/main/LangChain_Implementation_with_Claude_Anthropic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Langchain Implementation with Claude Anthropic

# %%
import getpass

API_KEY = getpass.getpass("Enter your Claude Anthropic API key: ")
print("API key loaded safely!")
# Out:
# Enter your Claude Anthropic API key: ··········
# API key loaded safely!

# %%
# !pip install langchain

# %%
# !pip install langchain-anthropic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.5/371.5 kB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.8/473.8 kB 44.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.80
#     Uninstalling langchain-core-0.3.80:
#       Successfully uninstalled langchain-core-0.3.80
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.1.0 which is incompatible.
# ...

# %%
from langchain_anthropic import ChatAnthropic

# %%
model = ChatAnthropic(model="claude-3-5-sonet-20240620",anthropic_api_key=API_KEY)

# %%
# Since i don't have any credit balance it will not work.

# %%
prompt="what is the currency of Nepal?"
output=model.invoke(prompt)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# /tmp/ipython-input-2091559125.py in <cell line: 0>()
#       1 prompt="what is the currency of Nepal?"
# ----> 2 output=model.invoke(prompt)
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     396             cast(
#     397                 "ChatGeneration",
# --> 398                 self.generate_prompt(
#     399                     [self._convert_input(input)],
#     400                     stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1115     ) -> LLMResult:
#    1116         prompt_messages = [p.to_messages() for p in prompts]
# ...

# %%
print(output)

# %%
# if you have credits this will work.
